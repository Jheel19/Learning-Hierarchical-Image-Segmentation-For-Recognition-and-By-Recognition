# %%
# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1+cu116 --index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu116
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp310-cp310-linux_x86_64.whl (1977.9 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.10.1 requires torch>=2, but you have torch 1.13.1+cu116 which is incompatible.
# torchmetrics 1.6.0 requires torch>=2.0.0, but you have torch 1.13.1+cu116 which is incompatible.
# ...

# %%
# !pip install torchdata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# ...

# %%
import yaml

# Load the YAML file
with open('/content/CAST/environment.yaml', 'r') as file:
    env_data = yaml.safe_load(file)

# Extract dependencies
dependencies = env_data.get('dependencies', [])

# Install pip dependencies
for dep in dependencies:
    if isinstance(dep, str):  # If it's a pip package
        # !pip install {dep}
    elif isinstance(dep, dict) and 'pip' in dep:  # If it's a pip section
        for pip_dep in dep['pip']:
            # !pip install {pip_dep}
# Out:
# ERROR: Invalid requirement: 'python=3.9': Expected end or semicolon (after name and no valid version specifier)
#     python=3.9
#           ^
# Hint: = is not a valid operator. Did you mean == ?
# ...
# ERROR: Invalid requirement: 'pytorch-cuda=11.6': Expected end or semicolon (after name and no valid version specifier)
#     pytorch-cuda=11.6
#                 ^
# Hint: = is not a valid operator. Did you mean == ?
# ERROR: Could not find a version that satisfies the requirement pytorch==1.13.1 (from versions: 0.1.2, 1.0.2)
# ERROR: No matching distribution found for pytorch==1.13.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 49.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.1 MB/s eta 0:00:00
# ...

# %%
# !pip install dgl==1.1.3+cu121 -f https://data.dgl.ai/wheels/cu121/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/cu121/repo.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.7 MB/s eta 0:00:00
# ...

# %%
# !wget http://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip
# !wget http://data.csail.mit.edu/places/ADEchallenge/release_test.zip
# Out:
# --2024-12-25 13:41:47--  http://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip
# Resolving data.csail.mit.edu (data.csail.mit.edu)... 128.52.131.233
# Connecting to data.csail.mit.edu (data.csail.mit.edu)|128.52.131.233|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip [following]
# --2024-12-25 13:41:47--  https://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip
# Connecting to data.csail.mit.edu (data.csail.mit.edu)|128.52.131.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 967382037 (923M) [application/zip]
# Saving to: ‘ADEChallengeData2016.zip’
#
# ADEChallengeData201 100%[===================>] 922.57M  47.6MB/s    in 20s
#
# 2024-12-25 13:42:07 (46.3 MB/s) - ‘ADEChallengeData2016.zip’ saved [967382037/967382037]

# %%
# !git clone https://github.com/twke18/CAST
# Out:
# Cloning into 'CAST'...
# remote: Enumerating objects: 1289, done.
# remote: Counting objects: 100% (313/313), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 1289 (delta 131), reused 300 (delta 125), pack-reused 976 (from 1)
# Receiving objects: 100% (1289/1289), 41.99 MiB | 41.11 MiB/s, done.
# Resolving deltas: 100% (582/582), done.

# %%
import os
import zipfile


# Create the directory
output_dir = '/content/CAST/data/ade20k'
os.makedirs(output_dir, exist_ok=True)

# Download the dataset
zip_file_path = '/content/ADEChallengeData2016.zip'


# Unzip the dataset
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_dir)

print(f"Dataset extracted to {output_dir}")
# Out:
# Dataset extracted to /content/CAST/data/ade20k

# %%
# !wget  best_checkpoint.pth https://huggingface.co/twke/CAST/resolve/main/snapshots/deit/imagenet1k/cast_small/best_checkpoint.pth
# Out:
# --2024-12-25 13:41:33--  http://best_checkpoint.pth/
# Resolving best_checkpoint.pth (best_checkpoint.pth)... failed: Name or service not known.
# wget: unable to resolve host address ‘best_checkpoint.pth’
# --2024-12-25 13:41:33--  https://huggingface.co/twke/CAST/resolve/main/snapshots/deit/imagenet1k/cast_small/best_checkpoint.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.61, 3.165.160.11, 3.165.160.59, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.61|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/CAST/
# Out:
# /content/CAST

# %%
# !wget https://huggingface.co/twke/CAST/resolve/main/snapshots.zip
# Out:
# --2024-12-25 13:53:20--  https://huggingface.co/twke/CAST/resolve/main/snapshots.zip
# Resolving huggingface.co (huggingface.co)... 3.165.160.59, 3.165.160.11, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import zipfile
import os

# Path to the zip file
zip_file_path = '/content/CAST/snapshots.zip'

# Path where you want to extract the contents
extract_to_path = '/content/CAST/'

# Create the directory if it doesn't exist
os.makedirs(extract_to_path, exist_ok=True)

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print(f"Extracted to: {extract_to_path}")
# Out:
# Extracted to: /content/CAST/

# %%
# %cd /content/CAST/
# Out:
# /content/CAST

# %%
import torch
torch.cuda.empty_cache()

# %%
# !bash /content/CAST/scripts/segmenter/train_ade20k_cast.sh
# Out:
# ERROR:root:No token file found. Also make sure that a [prod] section with a 'token = value' assignment exists.
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# Starting process with rank 0...
# Process 0 is connected.
# All processes are connected.
# Use normalization: {'mean': (123.68, 116.28, 103.53), 'std': (58.4, 57.12, 57.38)}
# 2024-12-25 14:14:29,776 - mmseg - INFO - Loaded 20210 images
# INFO:mmseg:Loaded 20210 images
# ...
